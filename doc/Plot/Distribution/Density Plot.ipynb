# %% [markdown]
# # 图22 密度图
#
# 密度图是可视化连续变量分布的常用工具.

# %%
from doc.Plot.require import *

# Import Data
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
# df = pd.read_csv("../data/mpg_ggplot2.csv")

# Draw Plot
plt.figure(figsize=(16, 10), dpi=60)
sns.kdeplot(df.loc[df['cyl'] == 4, "cty"], fill=True, color="g", label="Cyl=4", alpha=0.7)
sns.kdeplot(df.loc[df['cyl'] == 5, "cty"], fill=True, color="deeppink", label="Cyl=5", alpha=0.7)
sns.kdeplot(df.loc[df['cyl'] == 6, "cty"], fill=True, color="dodgerblue", label="Cyl=6", alpha=0.7)
sns.kdeplot(df.loc[df['cyl'] == 8, "cty"], fill=True, color="orange", label="Cyl=8", alpha=0.7)

# Decoration
plt.title('Density Plot of City Mileage by n_Cylinders', fontsize=22)
plt.legend()

plt.show()
